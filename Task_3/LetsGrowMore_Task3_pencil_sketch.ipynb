# %% [markdown]
# # Image to Pencil Sketch With Python

# %% [markdown]
# Data Science Project
#
# By
#
# Vinodhini Rajamnickam

# %% [markdown]
# ## import libraies

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Read the image

# %%
#image path
input_image_path = "butterfly-1829404_640.jpg"

# %%
image = cv2.imread(input_image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 2: Convert to grayscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 3: Invert the grayscale image

# %%
inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Grayscale Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## # Step 4: Apply Gaussian Blur

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 5: Invert the blurred image back

# %%
inverted_blurred_image = cv2.bitwise_not(blurred_image)
plt.imshow(inverted_blurred_image, cmap='gray')
plt.title('Inverted Blurred Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 6: Create the pencil sketch effect

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred_image, scale=256.0)
plt.imshow(pencil_sketch, cmap='gray')
plt.title('Pencil Sketch')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 7: Save the output image

# %%
output_image_path = "butterfly_pencil_sketch_output.jpg"
cv2.imwrite(output_image_path, pencil_sketch)
# Out:
# True

# %% [markdown]
# ## Display both original and pencil sketch images

# %%
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Pencil Sketch
plt.subplot(1, 2, 2)
plt.title('Pencil Sketch')
plt.imshow(pencil_sketch, cmap='gray')
plt.axis('off')

# Save the output image
cv2.imwrite(output_image_path, pencil_sketch)

# Show the plot
plt.tight_layout()
plt.show()
